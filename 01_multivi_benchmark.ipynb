# %% [markdown]
# # CMML3 Mini-project 2: MultiVI benchmark
#
# This notebook runs the full benchmark script in the same folder. Keep `01_multivi_benchmark.py` beside this notebook when submitting or running.

# %%
# %run 01_multivi_benchmark.py
